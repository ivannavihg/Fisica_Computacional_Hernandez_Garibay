# %% [markdown]
# # Tarea 17

# %%
using PyPlot
plt=PyPlot
# Out:
# PyPlot

# %% [markdown]
# __Ejercicio 4:__ Construya el propagador $e^{A t}$ para cada tiempo sobre una malla y uselo para propagar un estado inicial $\vec x_0$ cualquiera. Utilice:
# $$A=\left(\begin{array}{cc} -1 & 1\\ -1 & -1 \end{array} \right).$$
# * Grafique la trayectoria en el espacio de fase.

# %%
T=linspace(0,1,1000)
Z=[-1 1 ; -1 -1]
z0 = [1,1]
Zrx=[]
Zry=[]
for t in T
    vals=eigvals(t*Z)
    w=eigvecs(t*Z)
    d = diagm(exp.(vals))
    Z2=w*d*inv(w)
    Vec=Z2*z0
    push!(Zrx,Vec[1])
    push!(Zry,Vec[2])
end
plt.plot(Zrx,Zry)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x12ab73110>)
# /Users/ivanhernandezgaribay/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x12aba2890>
